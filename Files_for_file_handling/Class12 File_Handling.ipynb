# %%
file = open('student.txt', 'w')
for i in range(3):
    name = input('Name')
    age = int(input('Age'))
    marks = int(input('marks'))
    file.write(f'Name: {name} \n')
    file.write(f'Age: {age} \n')
    file.write(f'Marks: {marks} \n')
# Out:
# NameRavi
# Age22
# marks90
# NameHello
# Age20
# marks50
# NameHi
# Age22
# marks40

# %%
file.close()

# %%
with open('student.txt', 'a') as file:
    for i in range(3):
        name = input('Name')
        age = int(input('Age'))
        marks = int(input('marks'))
        file.write(f'Name: {name} \n')
        file.write(f'Age: {age} \n')
        file.write(f'Marks: {marks} \n')
# Out:
# NameAbhijeet
# Age23
# marks50
# NameMohit
# Age20
# marks90
# NameShivam
# Age20
# marks90

# %%
file = open('temp.txt', 'a+')
file.close()

# %%
def divide(a, b):
    try:
        return a/b, a%b
    except:
        print('Zero cant be your divisor')
    finally:
        print('Hello')

# %%
print(divide(10, '2'))
# Out:
# Zero cant be your divisor
# Hello
# None

# %%
with open('example.json', 'r') as file:
    print(file.read(100))
    print(type(file.read(100)))
# Out:
# {
#     "-HvXd_vqJ5A": {
#         "E_001781_001789": {
#             "event": 1,
#             "segments":
# <class 'str'>

# %%
import json

# %%
with open('example.json', 'r') as file:
    text = json.load(file)
    print(text)
# Out:
# {'-HvXd_vqJ5A': {'E_001781_001789': {'event': 1, 'segments': None, 'timestamps': [[1781.76, 1789.16]]}, 'E_001805_001812': {'event': 1, 'segments': None, 'timestamps': [[1805.48, 1812.92]]}, 'E_001952_001988': {'event': 4, 'segments': None, 'timestamps': [[1952.72, 1988.76]]}, 'E_002003_002088': {'event': 3, 'segments': None, 'timestamps': [[2003.04, 2088.76]]}, 'E_002096_002195': {'event': 2, 'segments': None, 'timestamps': [[2096.64, 2195.28]]}, 'E_002214_002222': {'event': 1, 'segments': None, 'timestamps': [[2214.8, 2222.12]]}, 'E_002242_002259': {'event': 1, 'segments': None, 'timestamps': [[2242.0, 2259.12]]}, 'E_002288_002297': {'event': 1, 'segments': None, 'timestamps': [[2288.52, 2297.28]]}, 'E_002325_002357': {'event': 4, 'segments': None, 'timestamps': [[2325.24, 2357.8]]}, 'E_002490_002586': {'event': 2, 'segments': None, 'timestamps': [[2490.68, 2586.2]]}, 'E_002600_002608': {'event': 1, 'segments': None, 'timestamps': [[2600.28, 2608.08]]}, 'E_002675_002710': {'event': 4, 'segments': None, 'timestamps': [[2675.68, 2710.72]]}, 'E_002738_002833': {'event': 3, 'segments': None, 'timestamps': [[2738.88, 2833.52]]}, 'E_002907_003007': {'event': 2, 'segments': None, 'timestamps': [[2907.0, 3007.44]]}, 'E_003060_003068': {'event': 1, 'segments': None, 'timestamps': [[3060.8, 3068.84]]}, 'E_003189_003289': {'event': 3, 'segments': None, 'timestamps': [[3189.6, 3289.36]]}, 'E_003299_003400': {'event': 2, 'segments': None, 'timestamps': [[3299.36, 3400.2]]}, 'E_003416_003451': {'event': 4, 'segments': None, 'timestamps': [[3416.8, 3451.64]]}, 'E_003771_003778': {'event': 1, 'segments': None, 'timestamps': [[3771.16, 3778.8]]}, 'E_003808_003849': {'event': 4, 'segments': None, 'timestamps': [[3808.28, 3849.92]]}, 'E_003857_003958': {'event': 3, 'segments': None, 'timestamps': [[3857.8, 3958.44]]}, 'E_003966_004070': {'event': 2, 'segments': None, 'timestamps': [[3966.4, 4070.88]]}, 'E_004100_004107': {'event': 1, 'segments': None, 'timestamps': [[4100.76, 4107.68]]}, 'E_004138_004169': {'event': 4, 'segments': None, 'timestamps': [[4138.92, 4169.8]]}, 'E_004206_004301': {'event': 3, 'segments': None, 'timestamps': [[4206.88, 4301.12]]}, 'E_004350_004455': {'event': 2, 'segments': None, 'timestamps': [[4350.04, 4455.48]]}, 'E_004488_004496': {'event': 1, 'segments': None, 'timestamps': [[4488.32, 4496.32]]}, 'E_004531_004562': {'event': 4, 'segments': None, 'timestamps': [[4531.0, 4562.08]]}, 'E_004572_004661': {'event': 3, 'segments': None, 'timestamps': [[4572.0, 4661.48]]}, 'E_004671_004771': {'event': 2, 'segments': None, 'timestamps': [[4671.28, 4771.24]]}, 'E_004786_004794': {'event': 1, 'segments': None, 'timestamps': [[4786.8, 4794.32]]}, 'E_004808_004838': {'event': 4, 'segments': None, 'timestamps': [[4808.52, 4838.72]]}, 'E_004848_004926': {'event': 3, 'segments': None, 'timestamps': [[4848.52, 4926.56]]}, 'E_004963_004992': {'event': 4, 'segments': None, 'timestamps': [[4963.88, 4992.96]]}, 'E_005030_005129': {'event': 3, 'segments': None, 'timestamps': [[5030.68, 5129.76]]}, 'E_005512_005551': {'event': 4, 'segments': None, 'timestamps': [[5512.24, 5551.24]]}, 'E_005561_005653': {'event': 3, 'segments': None, 'timestamps': [[5561.96, 5653.44]]}, 'E_005706_005809': {'event': 2, 'segments': None, 'timestamps': [[5706.32, 5809.96]]}, 'E_005832_005839': {'event': 1, 'segments': None, 'timestamps': [[5832.56, 5839.68]]}, 'E_005904_005938': {'event': 4, 'segments': None, 'timestamps': [[5904.0, 5938.6]]}, 'E_006000_006095': {'event': 3, 'segments': None, 'timestamps': [[6000.2, 6095.2]]}, 'E_006102_006204': {'event': 2, 'segments': None, 'timestamps': [[6102.84, 6204.72]]}, 'E_006224_006232': {'event': 1, 'segments': None, 'timestamps': [[6224.6, 6232.44]]}, 'E_006249_006285': {'event': 4, 'segments': None, 'timestamps': [[6249.96, 6285.52]]}, 'E_006296_006394': {'event': 3, 'segments': None, 'timestamps': [[6296.48, 6394.0]]}, 'E_006401_006501': {'event': 2, 'segments': None, 'timestamps': [[6401.64, 6501.44]]}, 'E_ ...

# %%
text['-HvXd_vqJ5A']
# Out:
# {'E_001781_001789': {'event': 1,
#   'segments': None,
#   'timestamps': [[1781.76, 1789.16]]},
#  'E_001805_001812': {'event': 1,
#   'segments': None,
#   'timestamps': [[1805.48, 1812.92]]},
#  'E_001952_001988': {'event': 4,
#   'segments': None,
#   'timestamps': [[1952.72, 1988.76]]},
#  'E_002003_002088': {'event': 3,
#   'segments': None,
#   'timestamps': [[2003.04, 2088.76]]},
#  'E_002096_002195': {'event': 2,
#   'segments': None,
#   'timestamps': [[2096.64, 2195.28]]},
#  'E_002214_002222': {'event': 1,
#   'segments': None,
#   'timestamps': [[2214.8, 2222.12]]},
#  'E_002242_002259': {'event': 1,
#   'segments': None,
#   'timestamps': [[2242.0, 2259.12]]},
#  'E_002288_002297': {'event': 1,
#   'segments': None,
#   'timestamps': [[2288.52, 2297.28]]},
#  'E_002325_002357': {'event': 4,
#   'segments': None,
#   'timestamps': [[2325.24, 2357.8]]},
#  'E_002490_002586': {'event': 2,
#   'segments': None,
#   'timestamps': [[2490.68, 2586.2]]},
#  'E_002600_002608': {'event': 1,
#   'segments': None,
#   'timestamps': [[2600.28, 2608.08]]},
#  'E_002675_002710': {'event': 4,
#   'segments': None,
#   'timestamps': [[2675.68, 2710.72]]},
#  'E_002738_002833': {'event': 3,
#   'segments': None,
#   'timestamps': [[2738.88, 2833.52]]},
#  'E_002907_003007': {'event': 2,
#   'segments': None,
#   'timestamps': [[2907.0, 3007.44]]},
#  'E_003060_003068': {'event': 1,
#   'segments': None,
#   'timestamps': [[3060.8, 3068.84]]},
#  'E_003189_003289': {'event': 3,
#   'segments': None,
#   'timestamps': [[3189.6, 3289.36]]},
#  'E_003299_003400': {'event': 2,
#   'segments': None,
#   'timestamps': [[3299.36, 3400.2]]},
#  'E_003416_003451': {'event': 4,
#   'segments': None,
#   'timestamps': [[3416.8, 3451.64]]},
#  'E_003771_003778': {'event': 1,
#   'segments': None,
#   'timestamps': [[3771.16, 3778.8]]},
#  'E_003808_003849': {'event': 4,
#   'segments': None,
#   'timestamps': [[3808.28, 3849.92]]},
#  'E_003857_003958': {'event': 3,
#   'segments': None,
#   'timestamps': [[3857.8, 3958.44]]},
#  'E_003966_004070': {'event': 2,
#   'segments': None,
#   'timestamps': [[3966.4, 4070.88]]},
#  'E_004100_004107': {'event': 1,
#   'segments': None,
#   'timestamps': [[4100.76, 4107.68]]},
#  'E_004138_004169': {'event': 4,
#   'segments': None,
#   'timestamps': [[4138.92, 4169.8]]},
#  'E_004206_004301': {'event': 3,
#   'segments': None,
#   'timestamps': [[4206.88, 4301.12]]},
#  'E_004350_004455': {'event': 2,
#   'segments': None,
#   'timestamps': [[4350.04, 4455.48]]},
#  'E_004488_004496': {'event': 1,
#   'segments': None,
#   'timestamps': [[4488.32, 4496.32]]},
#  'E_004531_004562': {'event': 4,
#   'segments': None,
#   'timestamps': [[4531.0, 4562.08]]},
#  'E_004572_004661': {'event': 3,
#   'segments': None,
#   'timestamps': [[4572.0, 4661.48]]},
#  'E_004671_004771': {'event': 2,
#   'segments': None,
#   'timestamps': [[4671.28, 4771.24]]},
#  'E_004786_004794': {'event': 1,
#   'segments': None,
#   'timestamps': [[4786.8, 4794.32]]},
#  'E_004808_004838': {'event': 4,
#   'segments': None,
#   'timestamps': [[4808.52, 4838.72]]},
#  'E_004848_004926': {'event': 3,
#   'segments': None,
#   'timestamps': [[4848.52, 4926.56]]},
#  'E_004963_004992': {'event': 4,
#   'segments': None,
#   'timestamps': [[4963.88, 4992.96]]},
#  'E_005030_005129': {'event': 3,
#   'segments': None,
#   'timestamps': [[5030.68, 5129.76]]},
#  'E_005512_005551': {'event': 4,
#   'segments': None,
#   'timestamps': [[5512.24, 5551.24]]},
#  'E_005561_005653': {'event': 3,
#   'segments': None,
#   'timestamps': [[5561.96, 5653.44]]},
#  'E_005706_005809': {'event': 2,
#   'segments': None,
#   'timestamps': [[5706.32, 5809.96]]},
#  'E_005832_005839': {'event': 1,
#   'segments': None,
#   'timestamps': [[5832.56, 5839.68]]},
#  'E_005904_005938': {'event': 4,
#   'segments': None,
#   'timestamps': [[5904.0, 5938.6]]},
#  'E_006000_006095': {'event': 3,
#   'segments': None,
#   'timestamps': [[6000.2, 6095.2]]},
#  'E_006102_006204': {'event': 2,
#   'segments': None,
#   'timestamps': [[6102.84, 6204.72]]},
#  'E_006224_006232': {'event': 1,
#   'segments': None,
#   'timestamps': [[6224.6, 6232.44]]},
#  'E_006249_006285': {'event': 4,
#   'segments': None,
#   'timestamps': [[6249.96, 6285.52]]},
#  'E_006296_006394': {'event': 3,
#   'segments': None,
#   'timestamps': [[6296.48, 6394.0]]},
#  'E_006401_006501': {'event': 2,
#   'segments': None,
#   'timestamps': [[6401.64, 6501.44]]},
#  'E_006522_006554': {'event': 4,
#   'segments': None,
#   'timestamps': [[6522.36, 6554.32]]},
#  'E_006565_006650': {'event': 3,
#   'segments': None,
#   'timestamps': [[6565.08, 6650.8]]},
#  'E_006659_006760': {'event': 2,
#   'segments': None,
#   'timestamps': [[6659.52, 6760.36]]},
#  'E_006779_006810': {'event': 4,
#   'segments': None,
#   'timestamps': [[6779.04, 6810.52]]},
#  'E_006853_006954': {'event': 2,
#   'segments': None,
#   'timestamps': [[6853.88, 6954.44]]},
#  'E_007334_007341': {'event': 1,
#   'segments': None,
#   'timestamps': [[7334.64, 7341.8]]},
#  'E_007361_007391': {'event': 4,
#   'segments': None,
#   'timestamps': [[7361.28, 7391.12]]},
#  'E_007447_007542': {'event': 3,
#   'segments': None,
#   'timestamps': [[7447.36, 7542.28]]},
#  'E_007562_007662': {'event': 2,
#   'segments': None,
#   'timestamps': [[7562.56, 7662.0]]},
#  'E_007679_007686': {'event': 1,
#   'segments': None,
#   'timestamps': [[7679.96, 7686.68]]},
#  'E_007702_007737': {'event': 4,
#   'segments': None,
#   'timestamps': [[7702.72, 7737.0]]},
#  'E_007745_007837': {'event': 3,
#   'segments': None,
#   'timestamps': [[7745.64, 7837.08]]},
#  'E_007845_007946': {'event': 2,
#   'segments': None,
#   'timestamps': [[7845.8, 7946.16]]},
#  'E_007961_007968': {'event': 1,
#   'segments': None,
#   'timestamps': [[7961.36, 7968.4]]},
#  'E_007985_008022': {'event': 4,
#   'segments': None,
#   'timestamps': [[7985.28, 8022.88]]},
#  'E_008034_008131': {'event': 3,
#   'segments': None,
#   'timestamps': [[8034.0, 8131.32]]},
#  'E_008138_008242': {'event': 2,
#   'segments': None,
#   'timestamps': [[8138.8, 8242.76]]},
#  'E_008260_008267': {'event': 1,
#   'segments': None,
#   'timestamps': [[8260.4, 8267.56]]},
#  'E_008339_008347': {'event': 1,
#   'segments': None,
#   'timestamps': [[8339.92, 8347.16]]},
#  'E_008384_008417': {'event': 4,
#   'segments': None,
#   'timestamps': [[8384.0, 8417.56]]},
#  'E_008427_008518': {'event': 3,
#   'segments': None,
#   'timestamps': [[8427.28, 8518.2]]},
#  'E_008527_008631': {'event': 2,
#   'segments': None,
#   'timestamps': [[8527.04, 8631.24]]},
#  'E_008642_008745': {'event': 3,
#   'segments': None,
#   'timestamps': [[8642.08, 8745.28]]}}

# %%
type(text)
# Out:
# dict

# %%
file = open('example.txt', 'r')
text = file.read()
print(text, type(text))
text = json.loads(text)
print(type(text))
file.close()
# Out:
# {
#     "-HvXd_vqJ5A": {
#         "E_001781_001789": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     1781.76,
#                     1789.16
#                 ]
#             ]
#         },
#         "E_001805_001812": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     1805.48,
#                     1812.92
#                 ]
#             ]
#         },
#         "E_001952_001988": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     1952.72,
#                     1988.76
#                 ]
#             ]
#         },
#         "E_002003_002088": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     2003.04,
#                     2088.76
#                 ]
#             ]
#         },
#         "E_002096_002195": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     2096.64,
#                     2195.28
#                 ]
#             ]
#         },
#         "E_002214_002222": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     2214.8,
#                     2222.12
#                 ]
#             ]
#         },
#         "E_002242_002259": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     2242.0,
#                     2259.12
#                 ]
#             ]
#         },
#         "E_002288_002297": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     2288.52,
#                     2297.28
#                 ]
#             ]
#         },
#         "E_002325_002357": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     2325.24,
#                     2357.8
#                 ]
#             ]
#         },
#         "E_002490_002586": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     2490.68,
#                     2586.2
#                 ]
#             ]
#         },
#         "E_002600_002608": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     2600.28,
#                     2608.08
#                 ]
#             ]
#         },
#         "E_002675_002710": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     2675.68,
#                     2710.72
#                 ]
#             ]
#         },
#         "E_002738_002833": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     2738.88,
#                     2833.52
#                 ]
#             ]
#         },
#         "E_002907_003007": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     2907.0,
#                     3007.44
#                 ]
#             ]
#         },
#         "E_003060_003068": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     3060.8,
#                     3068.84
#                 ]
#             ]
#         },
#         "E_003189_003289": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     3189.6,
#                     3289.36
#                 ]
#             ]
#         },
#         "E_003299_003400": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     3299.36,
#                     3400.2
#                 ]
#             ]
#         },
#         "E_003416_003451": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     3416.8,
#                     3451.64
#                 ]
#             ]
#         },
#         "E_003771_003778": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     3771.16,
#                     3778.8
#                 ]
#             ]
#         },
#         "E_003808_003849": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     3808.28,
#                     3849.92
#                 ]
#             ]
#         },
#         "E_003857_003958": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     3857.8,
#                     3958.44
#                 ]
#             ]
#         },
#         "E_003966_004070": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     3966.4,
#                     4070.88
#                 ]
#             ]
#         },
#         "E_004100_004107": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4100.76,
#                     4107.68
#                 ]
#             ]
#         },
#         "E_004138_004169": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4138.92,
#                     4169.8
#                 ]
#             ]
#         },
#         "E_004206_004301": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4206.88,
#                     4301.12
#                 ]
#             ]
#         },
#         "E_004350_004455": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4350.04,
#                     4455.48
#                 ]
#             ]
#         },
#         "E_004488_004496": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4488.32,
#                     4496.32
#                 ]
#             ]
#         },
#         "E_004531_004562": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4531.0,
#                     4562.08
#                 ]
#             ]
#         },
#         "E_004572_004661": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4572.0,
#                     4661.48
#                 ]
#             ]
#         },
#         "E_004671_004771": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4671.28,
#                     4771.24
#                 ]
#             ]
#         },
#         "E_004786_004794": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4786.8,
#                     4794.32
#                 ]
#             ]
#         },
#         "E_004808_004838": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4808.52,
#                     4838.72
#                 ]
#             ]
#         },
#         "E_004848_004926": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4848.52,
#                     4926.56
#                 ]
#             ]
#         },
#         "E_004963_004992": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4963.88,
#                     4992.96
#                 ]
#             ]
#         },
#         "E_005030_005129": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     5030.68,
#                     5129.76
#                 ]
#             ]
#         },
#         "E_005512_005551": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     5512.24,
#                     5551.24
#                 ]
#             ]
#         },
#         "E_005561_005653": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     5561.96,
#                     5653.44
#                 ]
#             ]
#         },
#         "E_005706_005809": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     5706.32,
#                     5809.96
#                 ]
#             ]
#         },
#         "E_005832_005839": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     5832.56,
#                     5839.68
#                 ]
#             ]
#         },
#         "E_005904_005938": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     5904.0,
#                     5938.6
#                 ]
#             ]
#         },
#         "E_006000_006095": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6000.2,
#                     6095.2
#                 ]
#             ]
#         },
#         "E_006102_006204": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6102.84,
#                     6204.72
#                 ]
#             ]
#         },
#         "E_006224_006232": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6224.6,
#                     6232.44
#                 ]
#             ]
#         },
#         "E_006249_006285": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6249.96,
#                     6285.52
#                 ]
#             ]
#         },
#         "E_006296_006394": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6296.48,
#                     6394.0
#                 ]
#             ]
#         },
#         "E_006401_006501": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6401.64,
#                     6501.44
#                 ]
#             ]
#         },
#         "E_006522_006554": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6522.36,
#                     6554.32
#                 ]
#             ]
#         },
#         "E_006565_006650": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6565.08,
#                     6650.8
#                 ]
#             ]
#         },
#         "E_006659_006760": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6659.52,
#                     6760.36
#                 ]
#             ]
#         },
#         "E_006779_006810": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6779.04,
#                     6810.52
#                 ]
#             ]
#         },
#         "E_006853_006954": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6853.88,
#                     6954.44
#                 ]
#             ]
#         },
#         "E_007334_007341": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     7334.64,
#                     7341.8
#                 ]
#             ]
#         },
#         "E_007361_007391": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     7361.28,
#                     7391.12
#                 ]
#             ]
#         },
#         "E_007447_007542": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     7447.36,
#                     7542.28
#                 ]
#             ]
#         },
#         "E_007562_007662": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     7562.56,
#                     7662.0
#                 ]
#             ]
#         },
#         "E_007679_007686": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     7679.96,
#                     7686.68
#                 ]
#             ]
#         },
#         "E_007702_007737": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     7702.72,
#                     7737.0
#                 ]
#             ]
#         },
#         "E_007745_007837": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     7745.64,
#                     7837.08
#                 ]
#             ]
#         },
#         "E_007845_007946": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     7845.8,
#                     7946.16
#                 ]
#             ]
#         },
#         "E_007961_007968": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     7961.36,
#                     7968.4
#                 ]
#             ]
#         },
#         "E_007985_008022": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     7985.28,
#                     8022.88
#                 ]
#             ]
#         },
#         "E_008034_008131": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     8034.0,
#                     8131.32
#                 ]
#             ]
#         },
#         "E_008138_008242": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     8138.8,
#                     8242.76
#                 ]
#             ]
#         },
#         "E_008260_008267": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     8260.4,
#                     8267.56
#                 ]
#             ]
#         },
#         "E_008339_008347": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     8339.92,
#                     8347.16
#                 ]
#             ]
#         },
#         "E_008384_008417": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     8384.0,
#                     8417.56
#                 ]
#             ]
#         },
#         "E_008427_008518": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     8427.28,
#                     8518.2
#                 ]
#             ]
#         },
#         "E_008527_008631": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     8527.04,
#                     8631.24
#                 ]
#             ]
#         },
#         "E_008642_008745": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     8642.08,
#                     8745.28
#                 ]
#             ]
#         }
#     },
#     "-u8_gMUBodE": {
#         "E_000349_000412": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     349.44,
#                     412.4
#                 ]
#             ]
#         },
#         "E_000538_000559": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     538.08,
#                     559.76
#                 ]
#             ]
#         },
#         "E_000714_000805": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     714.44,
#                     805.36
#                 ]
#             ]
#         },
#         "E_001107_001201": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     1107.72,
#                     1201.12
#                 ]
#             ]
#         },
#         "E_001549_001557": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     1549.48,
#                     1557.6
#                 ]
#             ]
#         },
#         "E_001575_001671": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     1575.32,
#                     1671.56
#                 ]
#             ]
#         },
#         "E_001709_001738": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     1709.36,
#                     1738.52
#                 ]
#             ]
#         },
#         "E_001810_001888": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     1810.64,
#                     1888.68
#                 ]
#             ]
#         },
#         "E_002156_002252": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     2156.28,
#                     2252.04
#                 ]
#             ]
#         },
#         "E_002701_002726": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     2701.44,
#                     2726.92
#                 ]
#             ]
#         },
#         "E_002772_002867": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     2772.56,
#                     2867.68
#                 ]
#             ]
#         },
#         "E_002943_003030": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     2943.56,
#                     3030.04
#                 ]
#             ]
#         },
#         "E_003122_003221": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     3122.84,
#                     3221.56
#                 ]
#             ]
#         },
#         "E_003335_003436": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     3335.56,
#                     3436.96
#                 ]
#             ]
#         },
#         "E_003492_003522": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     3492.96,
#                     3522.08
#                 ]
#             ]
#         },
#         "E_003643_003679": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     3643.56,
#                     3679.0
#                 ]
#             ]
#         },
#         "E_003740_003839": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     3740.56,
#                     3839.12
#                 ]
#             ]
#         },
#         "E_003905_004002": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     3905.48,
#                     4002.32
#                 ]
#             ]
#         },
#         "E_004213_004286": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4213.92,
#                     4286.96
#                 ]
#             ]
#         },
#         "E_004376_004400": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4376.76,
#                     4400.72
#                 ]
#             ]
#         },
#         "E_004544_004626": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4544.24,
#                     4626.04
#                 ]
#             ]
#         },
#         "E_004849_004877": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4849.6,
#                     4877.56
#                 ]
#             ]
#         },
#         "E_004908_005004": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     4908.2,
#                     5004.68
#                 ]
#             ]
#         },
#         "E_005176_005183": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     5176.32,
#                     5183.92
#                 ]
#             ]
#         },
#         "E_005338_005440": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     5338.72,
#                     5440.96
#                 ]
#             ]
#         },
#         "E_005526_005622": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     5526.68,
#                     5622.12
#                 ]
#             ]
#         },
#         "E_005711_005742": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     5711.32,
#                     5742.44
#                 ]
#             ]
#         },
#         "E_006024_006056": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6024.32,
#                     6056.76
#                 ]
#             ]
#         },
#         "E_006287_006320": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6287.32,
#                     6320.0
#                 ]
#             ]
#         },
#         "E_006391_006399": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6391.64,
#                     6399.92
#                 ]
#             ]
#         },
#         "E_006453_006463": {
#             "event": 1,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6453.92,
#                     6463.16
#                 ]
#             ]
#         },
#         "E_006485_006511": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6485.68,
#                     6511.64
#                 ]
#             ]
#         },
#         "E_006635_006728": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6635.16,
#                     6728.52
#                 ]
#             ]
#         },
#         "E_006887_006954": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     6887.68,
#                     6954.2
#                 ]
#             ]
#         },
#         "E_007037_007099": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     7037.92,
#                     7099.4
#                 ]
#             ]
#         },
#         "E_007333_007428": {
#             "event": 2,
#             "segments": null,
#             "timestamps": [
#                 [
#                     7333.8,
#                     7428.32
#                 ]
#             ]
#         },
#         "E_007473_007503": {
#             "event": 4,
#             "segments": null,
#             "timestamps": [
#                 [
#                     7473.0,
#                     7503.36
#                 ]
#             ]
#         },
#         "E_007535_007618": {
#             "event": 3,
#             "segments": null,
#             "timestamps": [
#                 [
#                     7535.8,
#                     7618.16
#                 ]
#             ]
#         }
#     }
# } <class 'str'>
# <class 'dict'>

# %%
for i in text:
    print(i)
# Out:
# -HvXd_vqJ5A
# -u8_gMUBodE

# %%
text.keys(), text.values()
# Out:
# (dict_keys(['-HvXd_vqJ5A', '-u8_gMUBodE']),
#  dict_values([{'E_001781_001789': {'event': 1, 'segments': None, 'timestamps': [[1781.76, 1789.16]]}, 'E_001805_001812': {'event': 1, 'segments': None, 'timestamps': [[1805.48, 1812.92]]}, 'E_001952_001988': {'event': 4, 'segments': None, 'timestamps': [[1952.72, 1988.76]]}, 'E_002003_002088': {'event': 3, 'segments': None, 'timestamps': [[2003.04, 2088.76]]}, 'E_002096_002195': {'event': 2, 'segments': None, 'timestamps': [[2096.64, 2195.28]]}, 'E_002214_002222': {'event': 1, 'segments': None, 'timestamps': [[2214.8, 2222.12]]}, 'E_002242_002259': {'event': 1, 'segments': None, 'timestamps': [[2242.0, 2259.12]]}, 'E_002288_002297': {'event': 1, 'segments': None, 'timestamps': [[2288.52, 2297.28]]}, 'E_002325_002357': {'event': 4, 'segments': None, 'timestamps': [[2325.24, 2357.8]]}, 'E_002490_002586': {'event': 2, 'segments': None, 'timestamps': [[2490.68, 2586.2]]}, 'E_002600_002608': {'event': 1, 'segments': None, 'timestamps': [[2600.28, 2608.08]]}, 'E_002675_002710': {'event': 4, 'segments': None, 'timestamps': [[2675.68, 2710.72]]}, 'E_002738_002833': {'event': 3, 'segments': None, 'timestamps': [[2738.88, 2833.52]]}, 'E_002907_003007': {'event': 2, 'segments': None, 'timestamps': [[2907.0, 3007.44]]}, 'E_003060_003068': {'event': 1, 'segments': None, 'timestamps': [[3060.8, 3068.84]]}, 'E_003189_003289': {'event': 3, 'segments': None, 'timestamps': [[3189.6, 3289.36]]}, 'E_003299_003400': {'event': 2, 'segments': None, 'timestamps': [[3299.36, 3400.2]]}, 'E_003416_003451': {'event': 4, 'segments': None, 'timestamps': [[3416.8, 3451.64]]}, 'E_003771_003778': {'event': 1, 'segments': None, 'timestamps': [[3771.16, 3778.8]]}, 'E_003808_003849': {'event': 4, 'segments': None, 'timestamps': [[3808.28, 3849.92]]}, 'E_003857_003958': {'event': 3, 'segments': None, 'timestamps': [[3857.8, 3958.44]]}, 'E_003966_004070': {'event': 2, 'segments': None, 'timestamps': [[3966.4, 4070.88]]}, 'E_004100_004107': {'event': 1, 'segments': None, 'timestamps': [[4100.76, 4107.68]]}, 'E_004138_004169': {'event': 4, 'segments': None, 'timestamps': [[4138.92, 4169.8]]}, 'E_004206_004301': {'event': 3, 'segments': None, 'timestamps': [[4206.88, 4301.12]]}, 'E_004350_004455': {'event': 2, 'segments': None, 'timestamps': [[4350.04, 4455.48]]}, 'E_004488_004496': {'event': 1, 'segments': None, 'timestamps': [[4488.32, 4496.32]]}, 'E_004531_004562': {'event': 4, 'segments': None, 'timestamps': [[4531.0, 4562.08]]}, 'E_004572_004661': {'event': 3, 'segments': None, 'timestamps': [[4572.0, 4661.48]]}, 'E_004671_004771': {'event': 2, 'segments': None, 'timestamps': [[4671.28, 4771.24]]}, 'E_004786_004794': {'event': 1, 'segments': None, 'timestamps': [[4786.8, 4794.32]]}, 'E_004808_004838': {'event': 4, 'segments': None, 'timestamps': [[4808.52, 4838.72]]}, 'E_004848_004926': {'event': 3, 'segments': None, 'timestamps': [[4848.52, 4926.56]]}, 'E_004963_004992': {'event': 4, 'segments': None, 'timestamps': [[4963.88, 4992.96]]}, 'E_005030_005129': {'event': 3, 'segments': None, 'timestamps': [[5030.68, 5129.76]]}, 'E_005512_005551': {'event': 4, 'segments': None, 'timestamps': [[5512.24, 5551.24]]}, 'E_005561_005653': {'event': 3, 'segments': None, 'timestamps': [[5561.96, 5653.44]]}, 'E_005706_005809': {'event': 2, 'segments': None, 'timestamps': [[5706.32, 5809.96]]}, 'E_005832_005839': {'event': 1, 'segments': None, 'timestamps': [[5832.56, 5839.68]]}, 'E_005904_005938': {'event': 4, 'segments': None, 'timestamps': [[5904.0, 5938.6]]}, 'E_006000_006095': {'event': 3, 'segments': None, 'timestamps': [[6000.2, 6095.2]]}, 'E_006102_006204': {'event': 2, 'segments': None, 'timestamps': [[6102.84, 6204.72]]}, 'E_006224_006232': {'event': 1, 'segments': None, 'timestamps': [[6224.6, 6232.44]]}, 'E_006249_006285': {'event': 4, 'segments': None, 'timestamps': [[6249.96, 6285.52]]}, 'E_006296_006394': {'event': 3, 'segments': None, 'timestamps': [[6296.48, 6394.0]]}, 'E_006401_006501': {'event': 2, 'segments': None, 'timestamps': [[6401.64, 6501.44]]}, 'E_00 ...

# %%
d = {
    'India': 'Rohit Sharma',
    'Pakistan': 'Babar Azam',
    'Australia': 'Pat Cummins'
}

# %%
with open('captains.json', 'w') as file:
    json.dump(d, file)

# %%
string = 'Machine learning and data mining often employ the same methods and overlap significantly, but while machine learning focuses on prediction, based on known properties learned from the training data, data mining focuses on the discovery of (previously) unknown properties in the data (this is the analysis step of knowledge discovery in databases). Data mining uses many machine learning methods, but with different goals; on the other hand, machine learning also employs data mining methods as "unsupervised learning" or as a preprocessing step to improve learner accuracy. Much of the confusion between these two research communities (which do often have separate conferences and separate journals, ECML PKDD being a major exception) comes from the basic assumptions they work with: in machine learning, performance is usually evaluated with respect to the ability to reproduce known knowledge, while in knowledge discovery and data mining (KDD) the key task is the discovery of previously unknown knowledge. Evaluated with respect to known knowledge, an uninformed (unsupervised) method will easily be outperformed by other supervised methods, while in a typical KDD task, supervised methods cannot be used due to the unavailability of training data.'

# %%
sent = string.split('.')

# %%
my_dict = {}
for i in range(len(sent)):
    my_dict[str(i)] = sent[i]

# %%
my_dict
# Out:
# {'0': 'Machine learning and data mining often employ the same methods and overlap significantly, but while machine learning focuses on prediction, based on known properties learned from the training data, data mining focuses on the discovery of (previously) unknown properties in the data (this is the analysis step of knowledge discovery in databases)',
#  '1': ' Data mining uses many machine learning methods, but with different goals; on the other hand, machine learning also employs data mining methods as "unsupervised learning" or as a preprocessing step to improve learner accuracy',
#  '2': ' Much of the confusion between these two research communities (which do often have separate conferences and separate journals, ECML PKDD being a major exception) comes from the basic assumptions they work with: in machine learning, performance is usually evaluated with respect to the ability to reproduce known knowledge, while in knowledge discovery and data mining (KDD) the key task is the discovery of previously unknown knowledge',
#  '3': ' Evaluated with respect to known knowledge, an uninformed (unsupervised) method will easily be outperformed by other supervised methods, while in a typical KDD task, supervised methods cannot be used due to the unavailability of training data',
#  '4': ''}

# %%
with open('wiki.json', 'w') as file:
    json.dump(my_dict, file)

# %%
str(my_dict)
# Out:
# '{\'0\': \'Machine learning and data mining often employ the same methods and overlap significantly, but while machine learning focuses on prediction, based on known properties learned from the training data, data mining focuses on the discovery of (previously) unknown properties in the data (this is the analysis step of knowledge discovery in databases)\', \'1\': \' Data mining uses many machine learning methods, but with different goals; on the other hand, machine learning also employs data mining methods as "unsupervised learning" or as a preprocessing step to improve learner accuracy\', \'2\': \' Much of the confusion between these two research communities (which do often have separate conferences and separate journals, ECML PKDD being a major exception) comes from the basic assumptions they work with: in machine learning, performance is usually evaluated with respect to the ability to reproduce known knowledge, while in knowledge discovery and data mining (KDD) the key task is the discovery of previously unknown knowledge\', \'3\': \' Evaluated with respect to known knowledge, an uninformed (unsupervised) method will easily be outperformed by other supervised methods, while in a typical KDD task, supervised methods cannot be used due to the unavailability of training data\', \'4\': \'\'}'

# %%
json.dumps(my_dict)
# Out:
# '{"0": "Machine learning and data mining often employ the same methods and overlap significantly, but while machine learning focuses on prediction, based on known properties learned from the training data, data mining focuses on the discovery of (previously) unknown properties in the data (this is the analysis step of knowledge discovery in databases)", "1": " Data mining uses many machine learning methods, but with different goals; on the other hand, machine learning also employs data mining methods as \\"unsupervised learning\\" or as a preprocessing step to improve learner accuracy", "2": " Much of the confusion between these two research communities (which do often have separate conferences and separate journals, ECML PKDD being a major exception) comes from the basic assumptions they work with: in machine learning, performance is usually evaluated with respect to the ability to reproduce known knowledge, while in knowledge discovery and data mining (KDD) the key task is the discovery of previously unknown knowledge", "3": " Evaluated with respect to known knowledge, an uninformed (unsupervised) method will easily be outperformed by other supervised methods, while in a typical KDD task, supervised methods cannot be used due to the unavailability of training data", "4": ""}'
