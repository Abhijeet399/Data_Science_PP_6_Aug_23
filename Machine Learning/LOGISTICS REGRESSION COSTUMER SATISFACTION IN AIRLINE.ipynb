# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
train_df=pd.read_csv("C:/Users/Noni Shaurya/Downloads/Invistico_Airline.csv")

# %%
train_df
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 0          satisfied     Loyal Customer   65  Personal Travel       Eco
# 1          satisfied     Loyal Customer   47  Personal Travel  Business
# 2          satisfied     Loyal Customer   15  Personal Travel       Eco
# 3          satisfied     Loyal Customer   60  Personal Travel       Eco
# 4          satisfied     Loyal Customer   70  Personal Travel       Eco
# ...              ...                ...  ...              ...       ...
# 129875     satisfied  disloyal Customer   29  Personal Travel       Eco
# 129876  dissatisfied  disloyal Customer   63  Personal Travel  Business
# 129877  dissatisfied  disloyal Customer   69  Personal Travel       Eco
# 129878  dissatisfied  disloyal Customer   66  Personal Travel       Eco
# 129879  dissatisfied  disloyal Customer   38  Personal Travel       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# ...

# %%
train_df.isna().sum()
# Out:
# satisfaction                           0
# Customer Type                          0
# Age                                    0
# Type of Travel                         0
# Class                                  0
# Flight Distance                        0
# Seat comfort                           0
# Departure/Arrival time convenient      0
# Food and drink                         0
# Gate location                          0
# Inflight wifi service                  0
# Inflight entertainment                 0
# Online support                         0
# Ease of Online booking                 0
# On-board service                       0
# Leg room service                       0
# Baggage handling                       0
# Checkin service                        0
# Cleanliness                            0
# Online boarding                        0
# Departure Delay in Minutes             0
# Arrival Delay in Minutes             393
# dtype: int64

# %%
train_df['Arrival Delay in Minutes'].fillna(train_df['Arrival Delay in Minutes'].median(), inplace=True,axis=0)

# %%
train_df.isna().sum()
# Out:
# satisfaction                         0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Class                                0
# Flight Distance                      0
# Seat comfort                         0
# Departure/Arrival time convenient    0
# Food and drink                       0
# Gate location                        0
# Inflight wifi service                0
# Inflight entertainment               0
# Online support                       0
# Ease of Online booking               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Cleanliness                          0
# Online boarding                      0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# dtype: int64

# %%
train_df['satisfaction']=np.where(train_df['satisfaction']=='satisfied',1,0)

# %%
train_df
# Out:
#         satisfaction      Customer Type  Age   Type of Travel     Class  \
# 0                  1     Loyal Customer   65  Personal Travel       Eco
# 1                  1     Loyal Customer   47  Personal Travel  Business
# 2                  1     Loyal Customer   15  Personal Travel       Eco
# 3                  1     Loyal Customer   60  Personal Travel       Eco
# 4                  1     Loyal Customer   70  Personal Travel       Eco
# ...              ...                ...  ...              ...       ...
# 129875             1  disloyal Customer   29  Personal Travel       Eco
# 129876             0  disloyal Customer   63  Personal Travel  Business
# 129877             0  disloyal Customer   69  Personal Travel       Eco
# 129878             0  disloyal Customer   66  Personal Travel       Eco
# 129879             0  disloyal Customer   38  Personal Travel       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# ...

# %%
train_df['Customer Type']=np.where(train_df['Customer Type']=='Loyal Customer',1,0)

# %%
train_df
# Out:
#         satisfaction  Customer Type  Age   Type of Travel     Class  \
# 0                  1              1   65  Personal Travel       Eco
# 1                  1              1   47  Personal Travel  Business
# 2                  1              1   15  Personal Travel       Eco
# 3                  1              1   60  Personal Travel       Eco
# 4                  1              1   70  Personal Travel       Eco
# ...              ...            ...  ...              ...       ...
# 129875             1              0   29  Personal Travel       Eco
# 129876             0              0   63  Personal Travel  Business
# 129877             0              0   69  Personal Travel       Eco
# 129878             0              0   66  Personal Travel       Eco
# 129879             0              0   38  Personal Travel       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0                   265             0                                  0
# ...

# %%
train_df['Type of Travel']=np.where(train_df['Type of Travel']=='Personal Travel',1,0)

# %%
train_df
# Out:
#         satisfaction  Customer Type  Age  Type of Travel     Class  \
# 0                  1              1   65               1       Eco
# 1                  1              1   47               1  Business
# 2                  1              1   15               1       Eco
# 3                  1              1   60               1       Eco
# 4                  1              1   70               1       Eco
# ...              ...            ...  ...             ...       ...
# 129875             1              0   29               1       Eco
# 129876             0              0   63               1  Business
# 129877             0              0   69               1       Eco
# 129878             0              0   66               1       Eco
# 129879             0              0   38               1       Eco
#
#         Flight Distance  Seat comfort  Departure/Arrival time convenient  \
# 0                   265             0                                  0
# ...

# %%
dataset=pd.get_dummies(train_df,columns=['Class'])

# %%
dataset
# Out:
#         satisfaction  Customer Type  Age  Type of Travel  Flight Distance  \
# 0                  1              1   65               1              265
# 1                  1              1   47               1             2464
# 2                  1              1   15               1             2138
# 3                  1              1   60               1              623
# 4                  1              1   70               1              354
# ...              ...            ...  ...             ...              ...
# 129875             1              0   29               1             1731
# 129876             0              0   63               1             2087
# 129877             0              0   69               1             2320
# 129878             0              0   66               1             2450
# 129879             0              0   38               1             4307
#
#         Seat comfort  Departure/Arrival time convenient  Food and drink  \
# ...

# %%
dataset.isna().sum()
# Out:
# satisfaction                         0
# Customer Type                        0
# Age                                  0
# Type of Travel                       0
# Flight Distance                      0
# Seat comfort                         0
# Departure/Arrival time convenient    0
# Food and drink                       0
# Gate location                        0
# Inflight wifi service                0
# Inflight entertainment               0
# Online support                       0
# Ease of Online booking               0
# On-board service                     0
# Leg room service                     0
# Baggage handling                     0
# Checkin service                      0
# Cleanliness                          0
# Online boarding                      0
# Departure Delay in Minutes           0
# Arrival Delay in Minutes             0
# Class_Business                       0
# Class_Eco                            0
# Class_Eco Plus                       0
# dtype: int64

# %%
label=dataset['satisfaction']
dataset.drop('satisfaction',axis=1,inplace=True)

# %%
dataset
# Out:
#         Customer Type  Age  Type of Travel  Flight Distance  Seat comfort  \
# 0                   1   65               1              265             0
# 1                   1   47               1             2464             0
# 2                   1   15               1             2138             0
# 3                   1   60               1              623             0
# 4                   1   70               1              354             0
# ...               ...  ...             ...              ...           ...
# 129875              0   29               1             1731             5
# 129876              0   63               1             2087             2
# 129877              0   69               1             2320             3
# 129878              0   66               1             2450             3
# 129879              0   38               1             4307             3
#
#         Departure/Arrival time convenient  Food and drink  Gate location  \
# ...

# %%
label
# Out:
# 0         1
# 1         1
# 2         1
# 3         1
# 4         1
#          ..
# 129875    1
# 129876    0
# 129877    0
# 129878    0
# 129879    0
# Name: satisfaction, Length: 129880, dtype: int32

# %%
dataset=dataset.values
label=label.values

# %%
u=np.mean(dataset,axis=0) #axis=0 operation around row
std=np.std(dataset,axis=0)
dataset=(dataset-u)/std

# %%
split=0.8
X_train=dataset[:int(dataset.shape[0]*split),:]
X_test=dataset[int(dataset.shape[0]*split):,:]

# %%
Y_train=label[:int(dataset.shape[0]*split)]
Y_test=label[int(dataset.shape[0]*split):]

# %%
print(X_test.shape,Y_test.shape,X_train.shape,Y_train.shape)
# Out:
# (25976, 23) (25976,) (103904, 23) (103904,)

# %%
X_train.shape
# Out:
# (103904, 23)

# %%
dataset[:10,2:4]
# Out:
# array([[ 1.49395144, -1.6711027 ],
#        [ 1.49395144,  0.46985247],
#        [ 1.49395144,  0.15245757],
#        [ 1.49395144, -1.32255247],
#        [ 1.49395144, -1.58445195],
#        [ 1.49395144, -0.0851018 ],
#        [ 1.49395144, -1.70809965],
#        [ 1.49395144, -0.16493733],
#        [ 1.49395144, -1.85803467],
#        [ 1.49395144, -0.41417995]])

# %%
X_train[0]
# Out:
# array([ 0.47342178,  1.69135082,  1.49395144, -1.6711027 , -2.03779055,
#        -1.9582301 , -1.97544301, -0.75838329, -0.94716271,  0.45802246,
#        -1.16318119, -0.36161261, -0.36596177, -2.6976054 , -0.60154396,
#         1.31621673, -0.61276078, -1.04148541, -0.38648106, -0.39164371,
#        -0.95806953,  1.10790047, -0.27949898])

# %%
ones=np.ones((X_train.shape[0],1))
X_train=np.hstack((ones,X_train))
print(X_train.shape)
# Out:
# (103904, 24)

# %%
ones=np.ones((X_test.shape[0],1))
X_test=np.hstack((ones,X_test))
print(X_test.shape)
# Out:
# (25976, 24)

# %%
X_train[0]
# Out:
# array([ 1.        ,  0.47342178,  1.69135082,  1.49395144, -1.6711027 ,
#        -2.03779055, -1.9582301 , -1.97544301, -0.75838329, -0.94716271,
#         0.45802246, -1.16318119, -0.36161261, -0.36596177, -2.6976054 ,
#        -0.60154396,  1.31621673, -0.61276078, -1.04148541, -0.38648106,
#        -0.39164371, -0.95806953,  1.10790047, -0.27949898])

# %%
def hypothesis(X,theta):
    return 1 / (1 + np.exp(-1 * np.dot(X, theta)))  #np.dot does matrix multiply,dot product,internal matrix prod

# %%
def loss_func(X, Y, weights):
    
    h_x = hypothesis(X, weights)
    loss = np.mean(Y*np.log(h_x) + (1 - Y)*np.log((1 - h_x)))
    
    return -1*loss

# %%
def gradient(x, y, weight):
    
    y_pred = hypothesis(x, weight)
    grad = np.dot(x.T, (y - y_pred))
        
    return grad/x.shape[0]

# %%
def gradient_descent(x, y, learning_rate = 0.03):
    
    weight = np.zeros((x.shape[1], ))
    
    cost = []
    
    epoch = 10000
    
    for i in range(epoch):
        grad = gradient(x, y, weight)
        
        loss = loss_func(x, y, weight)
        cost.append(loss)

        weight = weight + learning_rate * grad
        
    return cost, weight

# %%
cost, theta = gradient_descent(X_train, Y_train)

# %%
cost[0],cost[-10:]
# Out:
# (0.6931471805599453,
#  [0.45907590635707723,
#   0.4590759038535824,
#   0.459075901350974,
#   0.4590758988492517,
#   0.45907589634841534,
#   0.45907589384846453,
#   0.4590758913493992,
#   0.4590758888512186,
#   0.4590758863539226,
#   0.45907588385751114])

# %%
plt.plot(cost)

# %%
def predict(X, theta):
    h_x = hypothesis(X, theta)
    
    if (h_x >= 0.5):
        return 1
    else:
        return 0

# %%
corr = 0
for i in range(X_test.shape[0]):
    pred = predict(X_test[i], theta)
    if pred == Y_test[i]:
        corr+=1
print(corr/X_test.shape[0])
# Out:
# 0.943293809670465
