# %%
import pandas as pd
import numpy as np

# %%
train_df = pd.read_csv('C:/Users/bhatt/OneDrive/Desktop/whisper-main/Titanic_Dataset/train.csv')
test_df = pd.read_csv('C:/Users/bhatt/OneDrive/Desktop/whisper-main/Titanic_Dataset/test.csv')

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.shape
# Out:
# (891, 12)

# %%
train_df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
train_df.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
train_df['Age'].fillna(train_df['Age'].median(), inplace=True)

# %%
train_df.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
train_df.drop('Cabin', inplace=True, axis=1)

# %%
train_df['Embarked'].fillna(train_df['Embarked'].value_counts().idxmax(), inplace=True)

# %%
train_df
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
train_df.drop('PassengerId', axis=1, inplace=True)
train_df.drop('Ticket', axis=1, inplace=True)
train_df.drop('Name', axis=1, inplace=True)

# %%
train_df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  28.0      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
# [891 rows x 8 columns]

# %%
train_df['TravelAlone'] = np.where((train_df['SibSp'] + train_df['Parch']) > 0, 1, 0)

# %%
train_df
# Out:
#      Survived  Pclass     Sex   Age  SibSp  Parch     Fare Embarked  \
# 0           0       3    male  22.0      1      0   7.2500        S
# 1           1       1  female  38.0      1      0  71.2833        C
# 2           1       3  female  26.0      0      0   7.9250        S
# 3           1       1  female  35.0      1      0  53.1000        S
# 4           0       3    male  35.0      0      0   8.0500        S
# ..        ...     ...     ...   ...    ...    ...      ...      ...
# 886         0       2    male  27.0      0      0  13.0000        S
# 887         1       1  female  19.0      0      0  30.0000        S
# 888         0       3  female  28.0      1      2  23.4500        S
# 889         1       1    male  26.0      0      0  30.0000        C
# 890         0       3    male  32.0      0      0   7.7500        Q
#
#      TravelAlone
# 0              1
# 1              1
# 2              0
# 3              1
# 4              0
# ..           ...
# 886            0
# ...

# %%
train_df.drop('SibSp', axis = 1, inplace=True)
train_df.drop('Parch', axis = 1, inplace=True)

# %%
train_df
# Out:
#      Survived  Pclass     Sex   Age     Fare Embarked  TravelAlone
# 0           0       3    male  22.0   7.2500        S            1
# 1           1       1  female  38.0  71.2833        C            1
# 2           1       3  female  26.0   7.9250        S            0
# 3           1       1  female  35.0  53.1000        S            1
# 4           0       3    male  35.0   8.0500        S            0
# ..        ...     ...     ...   ...      ...      ...          ...
# 886         0       2    male  27.0  13.0000        S            0
# 887         1       1  female  19.0  30.0000        S            0
# 888         0       3  female  28.0  23.4500        S            1
# 889         1       1    male  26.0  30.0000        C            0
# 890         0       3    male  32.0   7.7500        Q            0
#
# [891 rows x 7 columns]

# %%
train_df['Gender'] = np.where(train_df['Sex'] == 'male', 1, 0)
train_df.drop('Sex', axis=1, inplace=True)

# %%
train_df
# Out:
#      Survived  Pclass   Age     Fare Embarked  TravelAlone  Gender
# 0           0       3  22.0   7.2500        S            1       1
# 1           1       1  38.0  71.2833        C            1       0
# 2           1       3  26.0   7.9250        S            0       0
# 3           1       1  35.0  53.1000        S            1       0
# 4           0       3  35.0   8.0500        S            0       1
# ..        ...     ...   ...      ...      ...          ...     ...
# 886         0       2  27.0  13.0000        S            0       1
# 887         1       1  19.0  30.0000        S            0       0
# 888         0       3  28.0  23.4500        S            1       0
# 889         1       1  26.0  30.0000        C            0       1
# 890         0       3  32.0   7.7500        Q            0       1
#
# [891 rows x 7 columns]

# %%
print(pd.get_dummies(train_df['Embarked']))
# Out:
#      C  Q  S
# 0    0  0  1
# 1    1  0  0
# 2    0  0  1
# 3    0  0  1
# 4    0  0  1
# ..  .. .. ..
# 886  0  0  1
# 887  0  0  1
# 888  0  0  1
# 889  1  0  0
# 890  0  1  0
#
# [891 rows x 3 columns]
