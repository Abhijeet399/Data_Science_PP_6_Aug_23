# %%
import tensorflow as tf
import numpy as np
import matplotlib.pyplot as plt
from tensorflow.keras.applications.resnet import ResNet50
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet import preprocess_input, decode_predictions

# %%
model_Resnet = ResNet50()

# %%
model_Resnet.summary()
# Out:
# Model: "resnet50"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ...
#  input_1 (InputLayer)        [(None, 224, 224, 3)]        0         []
#
#  conv1_pad (ZeroPadding2D)   (None, 230, 230, 3)          0         ['input_1[0][0]']
#
#  conv1_conv (Conv2D)         (None, 112, 112, 64)         9472      ['conv1_pad[0][0]']
#
#  conv1_bn (BatchNormalizati  (None, 112, 112, 64)         256       ['conv1_conv[0][0]']
#  on)
#
#  conv1_relu (Activation)     (None, 112, 112, 64)         0         ['conv1_bn[0][0]']
#
#  pool1_pad (ZeroPadding2D)   (None, 114, 114, 64)         0         ['conv1_relu[0][0]']
#
#  pool1_pool (MaxPooling2D)   (None, 56, 56, 64)           0         ['pool1_pad[0][0]']
#
#  conv2_block1_1_conv (Conv2  (None, 56, 56, 64)           4160      ['pool1_pool[0][0]']
#  D)
#
# ...

# %%
path = 'C:/Users/bhatt/Downloads/'
img = image.load_img(path + 'download.jpg', target_size = (224, 224))

# %%
plt.imshow(img)

# %%
img = image.img_to_array(img)

# %%
print(img.shape)
img = np.expand_dims(img, axis = 0)
print(img.shape)
# Out:
# (224, 224, 3)
# (1, 224, 224, 3)

# %%
pred = model_Resnet.predict(img)
# Out:
# 1/1 [==============================] - 0s 107ms/step

# %%
np.argmax(pred)
# Out:
# 737

# %%
decode_predictions(pred, top = 5)
# Out:
# [[('n03983396', 'pop_bottle', 0.3171561),
#   ('n02823428', 'beer_bottle', 0.2760816),
#   ('n04557648', 'water_bottle', 0.043300703),
#   ('n02823750', 'beer_glass', 0.037366148),
#   ('n02837789', 'bikini', 0.026383603)]]

# %%
img = preprocess_input(img)

# %%
plt.imshow(img[0])
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
pred = model_Resnet.predict(img)
print(decode_predictions(pred, top = 5))
# Out:
# 1/1 [==============================] - 0s 112ms/step
# [[('n04418357', 'theater_curtain', 0.39947614), ('n10148035', 'groom', 0.17749992), ('n03617480', 'kimono', 0.097927965), ('n04591157', 'Windsor_tie', 0.080080666), ('n02883205', 'bow_tie', 0.036314018)]]
